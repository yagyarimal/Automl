# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv",encoding='latin1')
print(df.head()) 
x=df.drop(['GPAAA','GPAM','Result','Res','pff','Churn'],axis=1).values
y=df['Pf'].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(x_train,y_train)
reg.score(x_test,y_test)
import statsmodels.formula.api as smf
mod = smf.ols(formula='Pf~SLC+Plus+Physics+Math+Chemistry+Bio', data=df)
res = mod.fit()
print(res.summary())

# %%
# normalization using
from sklearn.metrics import accuracy_score
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv",encoding='latin1')
print(df.head())
x=df.drop(['Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
y=df['GPAM'].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_s=scaler.fit_transform(x_train)
x_test_s=scaler.fit_transform(x_test,y_train)
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)

# %%
y_predlr=lr.predict(x_test)
y_predlr

# %%
lr.score(x_test,y_test)

# %%
y_predlr = np.round(y_predlr)
y_predlr = y_predlr.astype(int)
y_predlr = np.array(y_test)
accuracy_score(y_predlr, y_test)

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv",encoding='latin1')
print(df.head()) 
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
y=df['GPAM'].values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(x_train,y_train)
reg.score(x_test,y_test)

# %%
from sklearn import svm
model=svm.SVC()
model.fit(x_train,y_train)
model.score(x_test,y_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=90)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)

# %%
#when second time run the sample size of each changes where the samples were changed t each time train and test splits will change
from sklearn.model_selection import KFold
kf=KFold(n_splits=3) # how many folds
kf

# %%
def get_score(model,x_train,x_test,y_train,y_test):
    model.fit(x_train,y_train)
    return model.score(x_test,y_test)

# %%
from sklearn.linear_model import LinearRegression
ml=LinearRegression()
ml.fit(x_train,y_train)
get_score(LinearRegression(),x_train,x_test,y_train,y_test)

# %%
from sklearn import svm
model=svm.SVC()
model.fit(x_train,y_train)
model.score(x_test,y_test)
get_score(model,x_train,x_test,y_train,y_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=50)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
get_score(RandomForestClassifier(n_estimators=80),x_train,x_test,y_train,y_test)

# %%
from sklearn.model_selection import StratifiedKFold # uniformed  distribution of sample
folds = StratifiedKFold(n_splits=3)
for train_index,test_index in kf.split([1,2,3,4,5,6,7,8,9]):
    print(test_index,train_index)

# %%
train_index

# %%
test_index

# %%
#intrative process of CV
import numpy as np
from sklearn.datasets import load_digits
digits=load_digits()
scores_logistic = []
scores_svm = []
scores_rf = []
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','Pf','Churn'],axis=1).values
y=df['GPAM'].values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
lr=LogisticRegression(max_iter=1000)
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
from sklearn import svm
model=svm.SVC()
model.fit(x_train,y_train)
model.score(x_test,y_test)
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=80)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
for train_index, test_index in folds.split(x,y):
    x_train, x_test, y_train, y_test = x[train_index], x[test_index],y[train_index], y[test_index]
    scores_logistic.append(get_score(LogisticRegression(solver='liblinear',multi_class='ovr'), x_train, x_test, y_train, y_test))  
    scores_svm.append(get_score(model, x_train, x_test, y_train, y_test))
    scores_rf.append(get_score(RandomForestClassifier(n_estimators=40), x_train, x_test, y_train, y_test))

# %%
scores_logistic

# %%
scores_rf# parameter tuning 40

# %%
scores_svm

# %%
# my data categorical Predicated
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv",encoding='latin1')
df["GPAAA"]=df["GPAAA"].astype("category")
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
y=df['GPAAA'].values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
lr=LogisticRegression()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score # did same as above
from sklearn import svm
from sklearn.svm import SVC
for train_index, test_index in folds.split(x,y):
    x_train, x_test, y_train, y_test = x[train_index], x[test_index],y[train_index], y[test_index]
    scores_logistic.append(get_score(LogisticRegression(solver='liblinear',multi_class='ovr'), x_train, x_test, y_train, y_test))  
    scores_svm.append(get_score(model, x_train, x_test, y_train, y_test))
    scores_rf.append(get_score(RandomForestClassifier(n_estimators=40), x_train, x_test, y_train, y_test))

# %%
scores_logistic

# %%
scores_rf# parameter tuning 40

# %%
scores_svm

# %%
from sklearn.model_selection import cross_val_score # did same as above

# %%
linearregression=cross_val_score(LogisticRegression(max_iter=1000),x, y)
linearregression

# %%
np.average(linearregression)

# %%
svv=cross_val_score(SVC(),digits.data, digits.target)
svv

# %%
np.average(svv)

# %%
scores1 = cross_val_score(RandomForestClassifier(n_estimators=5),digits.data, digits.target, cv=10)
np.average(scores1)

# %%
df.values

# %%
from sklearn.model_selection import StratifiedKFold # uniformed  distribution of sample
folds = StratifiedKFold(n_splits=5)
for train_index,test_index in kf.split(df.values):
    print(train_index,test_index)

# %%
#Overfit/underfit bagging Ensamble teachniques

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv",encoding='latin1')
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
y=df['GPAM'].values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
lr=LogisticRegression()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.GPAM.value_counts()

# %%
268/500 # ssome imbalance not major imbalance(1-100)

# %%
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
y=df['GPAM'].values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
lr=LogisticRegression()
y=df.GPAM

# %%
x,y

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler() # 
x_scaled=scaler.fit_transform(x)
x_scaled[:3]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,stratify=y,random_state=10)

# %%
x_train.shape

# %%
y_train.value_counts()

# %%
201/375

# %%
y_train.value_counts(normalize=True)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
scores=cross_val_score(DecisionTreeClassifier(),x,y,cv=5) # for imbalance data sets
scores

# %%
scores.mean()

# %%
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(
                 base_estimator=DecisionTreeClassifier(),
                 n_estimators=100, # 100 model
                 max_samples=0.8, # sampling
                 oob_score=True, ##  restricted un seen test data sets
                 random_state=0)
bag_model.fit(x_train,y_train)
bag_model.oob_score_

# %%
bag_model.score(x_test,y_test)

# %%
bag_model=BaggingClassifier(
                 base_estimator=DecisionTreeClassifier(),
                 n_estimators=100,
                 max_samples=0.8,
                 oob_score=True,
                 random_state=0)
score=cross_val_score(bag_model,x,y,cv=5)
score.mean()

# %%
from sklearn.ensemble import RandomForestClassifier
score=cross_val_score(RandomForestClassifier(),x,y,cv=5)
score.mean()

# %%
#Overfit/underfit bagging Ensamble teachniques

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv",encoding='latin1')
print(df.head()) 
x=df.drop(['GPAM','pff','Result','GPAAA','Res','Pf','Churn'],axis=1).values
y=df['Pf'].values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same

# %%
df.head()

# %%
df.isnull().sum()#df.describe() df.Outcome.value_counts()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler() # 
x_scaled=scaler.fit_transform(x)
x_scaled[:3]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,stratify=y,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
scores=cross_val_score(DecisionTreeClassifier(),x,y,cv=5) # for imbalance data sets
scores
scores.mean()

# %%
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(
                 base_estimator=DecisionTreeClassifier(),
                 n_estimators=100, # 100 model
                 max_samples=0.8, # sampling
                 oob_score=True, ##  restricted un seen test data sets
                 random_state=0)
bag_model.fit(x_train,y_train)
bag_model.oob_score_
bag_model.score(x_test,y_test)

# %%
bag_model=BaggingClassifier(
                 base_estimator=DecisionTreeClassifier(),
                 n_estimators=100,
                 max_samples=0.8,
                 oob_score=True,
                 random_state=0)
score=cross_val_score(bag_model,x,y,cv=5)
score.mean()

# %%
from sklearn.ensemble import RandomForestClassifier
score=cross_val_score(RandomForestClassifier(),x,y,cv=5)
score.mean()

# %%
#ensambel Bosting

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv",encoding='latin1')
print(df.head()) 
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
lr=LogisticRegression()
y=df['pff'].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(x_train,y_train)
reg.score(x_test,y_test)

# %%
x,y

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets,metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()#-3 to 3
x_scaled=scaler.fit_transform(x)
x_scaled

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,stratify=y,random_state=10)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=200)
adb=AdaBoostClassifier(n_estimators=200,random_state=1,learning_rate=.01)
xgc=GradientBoostingClassifier(n_estimators=200,random_state=1,learning_rate=.01)
xgf=xgb.XGBClassifier(n_estimators=200,random_state=1,learning_rate=.01)

# %%
x_test

# %%
rf.fit(x_train,y_train)
adb.fit(x_train,y_train)
xgc.fit(x_train,y_train)
xgf.fit(x_train,y_train)

# %%
print('Random Forest:',rf.score(x_test,y_test))
print('AdaBoost:',adb.score(x_test,y_test))
print('Gradient Boosting:',xgc.score(x_test,y_test)) 
print('XGBoosting:',xgf.score(x_test,y_test))

# %%
#SVM Categirucal
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head()) 
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','Pf','Churn'],axis=1).values
y=df['GPAM'].values
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)#random state=0 every time result same

# %%
dir(df)

# %%
import pandas as pd
from sklearn import model_selection
from sklearn. ensemble import AdaBoostClassifier
from sklearn.model_selection import KFold

# %%
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head()) 
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
y=df['pff'].values
array=df.values
seed=7
num_trees=30

# %%
y

# %%
kfold=model_selection.KFold(n_splits=10,shuffle=True,random_state=seed)
model=AdaBoostClassifier(n_estimators=num_trees,random_state=seed)
result=model_selection.cross_val_score(model,x,y,cv=kfold)
print(result.mean())

# %%
from sklearn import svm
from xgboost import XGBClassifier
XGBClassifier()
clf=XGBClassifier()
seed=7
num_trees=30
kfold=model_selection.KFold(n_splits=10,shuffle=True,random_state=seed)
model=XGBClassifier(n_estimators=num_trees,random_state=seed)
result=model_selection.cross_val_score(model,x,y,cv=4)
print(result.mean())

# %%
from sklearn.datasets import load_iris
iris=load_iris()
print(iris)

# %%
x=iris.data
y=iris.target
x,y

# %%
from sklearn.model_selection import KFold
kf=KFold(n_splits=5,shuffle=True)

# %%
print("training set    Test set")
for train_set,test_set in kf.split(x):
    print(train_set,test_set)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10)

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(rf,x,y,scoring='accuracy',cv=10))

# %%
accuracy=cross_val_score(rf,x,y,scoring='accuracy',cv=10).mean()*100
print("Accuracy",accuracy)

# %%
#Linear regression of categorial variables

# %%
import numpy as np
import pandas as pd
from statsmodels.formula.api import ols
from scipy import stats
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\Salary.csv",encoding='latin1')
print(df.head()) 
df

# %%
dummy=pd.get_dummies(df["gender"])
dummy=pd.concat([df,dummy],axis=1)
dummy

# %%
dummy

# %%
dummy.drop(["name","gender","Male"],inplace=True,axis=1)

# %%
dummy

# %%
dummy.columns=["age","income","salary","Female"]

# %%
dummy

# %%
import statsmodels.formula.api as smf
mod = smf.ols(formula='salary ~ age + income + Female', data=dummy)
res = mod.fit()
print(res.summary())

# %%
reg2=sm.OLS(dummy["salary"],sm.add_constant(dummy[["age","income","Female"]])).fit()
print(reg2.summary())

# %%
#Categorical  ordinal Variables

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\SalaryCopyCopy.csv",encoding='latin1')
df.sample(3)

# %%
df=df.iloc[:,5:]# left up 5 columns than all

# %%
df

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,0:1],df.iloc[:,-1],test_size=.2)#y=last column

# %%
x_train,

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['F','D+','C-','C','C+','B-','B','B+','A-','A']])

# %%
oe.fit(x_train)

# %%
x_train=oe.transform(x_train)
x_test=oe.transform(x_test)

# %%
x_train

# %%
#categorical data transformation

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\Salary - Copy.csv",encoding='latin1')
print(df.head()) 
df
df.dtypes

# %%
df["Grade"].unique()

# %%
df["gender"].unique()

# %%
ohe = OneHotEncoder(categories='auto')
feature_arr = ohe.fit_transform(df[['Grade','gender']]).toarray()
feature_labels = ohe.get_feature_names()

# %%
feature_labels = np.array(feature_labels).ravel()

# %%
features = pd.DataFrame(feature_arr, columns=feature_labels)

# %%
features.head()

# %%
features.rename(columns = {'x0_A':'A','x0_A-':'A-','x0_B':'B','x0_B+':'B+','x0_B-':'B-','x0_C':'C','x0_C-':'C-','x0_D':'D','x0_D+':'D+','x0_F':'F','x1_Female':'Female','x1_Male':'Male'}, inplace = True)

# %%
features.head()

# %%
final=pd.concat([df,features],axis=1)
final.head()

# %%
#laber encoder target variables

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\Salary - Copy.csv",encoding='latin1')
print(df.head())

# %%
df.dtypes

# %%
df["Grade"].unique()

# %%
df["Grade"].value_counts()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
df["Grade"]=label_encoder.fit_transform(df["Grade"])

# %%
df.head(7)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import skew
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize'] = (10, 10)

# %%
#Decision Tree
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split  
# loading the iris dataset
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head()) 
x=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff'],axis=1).values
y=df['GPAAA'].values 
# dividing X, y into train and test data
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 0)
# training a DescisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train)
dtree_predictions = dtree_model.predict(X_test)
# creating a confusion matrix
cm = confusion_matrix(y_test, dtree_predictions)
cm

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split  
# loading the iris dataset
iris = datasets.load_iris()  
# X -> features, y -> label
X = iris.data
y = iris.target  
# dividing X, y into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)  
# training a linear SVM classifier
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train, y_train)
svm_predictions = svm_model_linear.predict(X_test)  
# model accuracy for X_test  
accuracy = svm_model_linear.score(X_test, y_test)
# creating a confusion matrix
cm = confusion_matrix(y_test, svm_predictions)
cm

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split  
# loading the iris dataset
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head()) 
x=df.drop(['GPAM','Pf','Result','Res','pff','GPAAA','Churn'],axis=1).values
df["GPAAA"]=df["GPAAA"].astype("category")
y=df['GPAAA'].values
# dividing X, y into train and test data
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 0)
# training a KNN classifier
from sklearn.neighbors import KNeighborsClassifier# needs numberical dependent
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)
# accuracy on X_test
accuracy = knn.score(X_test, y_test)
print (accuracy)
# creating a confusion matrix
knn_predictions = knn.predict(X_test) 
cm = confusion_matrix(y_test, knn_predictions)
cm

# %%
# importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split  
# loading the iris dataset
iris = datasets.load_iris()  
# X -> features, y -> label
X = iris.data
y = iris.target  
# dividing X, y into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)  
# training a Naive Bayes classifier
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(X_train, y_train)
gnb_predictions = gnb.predict(X_test)  
# accuracy on X_test
accuracy = gnb.score(X_test, y_test)
print (accuracy ) 
# creating a confusion matrix
cm = confusion_matrix(y_test, gnb_predictions)
cm

# %%
#logistic regresion
import numpy as np
from sklearn.datasets import load_digits
digits=load_digits()
digits.data[0]

# %%
plt.gray()
import matplotlib.pyplot as plt
for i in range(5):
    plt.matshow(digits.images[i])

# %%
digits.target[0:5]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=.2)

# %%
len(x_train)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)

# %%
model.score(x_test,y_test)

# %%
plt.matshow(digits.images[6])

# %%
model.predict([digits.data[67]])

# %%
model.predict(digits.data[0:5])

# %%
# confusion matrix
ypred=model.predict(x_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,ypred)
cm

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel("Predicated")
plt.ylabel("Truth")

# %%
# multinominal
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head())

# %%
df.info()

# %%
df.dtypes

# %%
df["GPAAA"]=df["GPAAA"].astype("category")

# %%
df.dtypes

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df[["SLC","Plus","Physics","Math","Chemistry","Bio"]],df["GPAAA"],test_size=.3)

# %%
model=LogisticRegression(max_iter=1000)

# %%
model.fit(xtrain,ytrain)

# %%
predict=model.predict(xtest)

# %%
model.score(xtest,ytest)

# %%
#evaluation
from sklearn.metrics import confusion_matrix,plot_confusion_matrix
cm=confusion_matrix(ytest,predict)
cm

# %%
df.head()

# %%
plot_confusion_matrix(model,xtest,ytest)

# %%
#precision recall f1 score
from sklearn import metrics
from sklearn.metrics import accuracy_score
print(metrics.classification_report(ytest,predict))

# %%
#ROC Curve
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler,OneHotEncoder
from sklearn.linear_model import LogisticRegression
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head()) 
df[["GPAAA"]]=df[["GPAAA"]].astype("category")

# %%
x=df.drop(['GPAAA','GPAM','Pf','Res','Churn','pff'],axis=1)
y=df.Result
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3)
from sklearn .metrics import plot_roc_curve,plot_precision_recall_curve,roc_curve
y

# %%
y.value_counts()
x.columns

# %%
num_cols=['SLC','Plus','Physics','Math','Chemistry','Bio']
cat_cols=['Result']

# %%
ct=ColumnTransformer([ ('s1',RobustScaler(),num_cols),
                       ('s2',OneHotEncoder(sparse=False, handle_unknown='ignore'),cat_cols)])

# %%
p=Pipeline([ 
    ('ct',ct),
     ('mod',LogisticRegression(random_state=0)) ])
p

# %%
p.fit(xtrain,ytrain)

# %%
preds=p.predict(xtest)
preds[:50]

# %%
from sklearn.metrics import confusion_matrix,plot_confusion_matrix

# %%
confusion_matrix(ytest,preds)

# %%
p.classes_

# %%
confusion_matrix(ytest,preds,labels=(1,0))

# %%
tp,fn,fp,tn=confusion_matrix(ytest,preds,labels=(1,0)).ravel()

# %%
precision=tp/(tp+fn)
precision
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,fbeta_score,matthews_corrcoef
k= precision_score(ytest,preds)
print("Precision score:",k)
print("reacall score:",recall_score(ytest,preds))
print("F1 score:",f1_score(ytest,preds))
print("Fbeta score:",fbeta_score(ytest,preds,beta=.5))
print("mathews score:",matthews_corrcoef(ytest,preds))

# %%
plot_roc_curve(p,xtest,ytest)

# %%
plot_roc_curve(p,xtest,ytest) #plot_precision_recall_curve(p,x_test,y_test)
plt.plot([0,1],[0,1],c='k')

# %%
plot_precision_recall_curve(p,x_test,y_test)

# %%
ytest.value_counts()

# %%
46/41

# %%
plot_precision_recall_curve(p,xtest,ytest)
plt.plot([0,1],[1.12,1.12],c='k')
plt.legend(loc='best')

# %%
probs=p.predict_proba(xtest)[:,1]
probs
p.classes_

# %%
from sklearn.preprocessing import Binarizer
binarizer=Binarizer(threshold=.5)
s=binarizer.fit_transform([probs])
s
np.unique(s.ravel(),return_counts=True)

# %%
fpr,tpr,thr=roc_curve(ytest,probs)

# %%
plt.scatter(fpr,tpr)

# %%
pd.DataFrame({'fpr':fpr,
             'tpr':tpr,
             'thr':thr})

# %%
def plot_roc_curve_from_scratch(ytrue,thresholds):
    xax,yax=[],[]
    for thr in thresholds:
        preds=Binarizer(threshold=thr).fit_transform([probs]).ravel()
        tn,fp,fn,tp=confusion_matrix(ytest,preds).ravel()
        fpr1=fp/(fp+tn)
        tpr1=tp/(tp+fn)
        xax.append(fpr1)
        yax.append(tpr1)
    return xax,yax

# %%
xax,yax=plot_roc_curve_from_scratch(xtest,np.linspace(0,1,30))
plt.scatter(xax,yax)

# %%
  def plot_pr_curve_curve_from_scratch(ytrue,thresholds):
    xaxpr,yaxpr=[],[]
    for thr in thresholds:
        preds=Binarizer(threshold=thr).fit_transform([probs]).ravel()
        tn,fp,fn,tp=confusion_matrix(ytest,preds).ravel()
        preci=tp/(fp+tp)
        recall=tp/(tp+fn)
        xaxpr.append(preci)
        yaxpr.append(recall)
    return xaxpr,yaxpr

# %%
xaxpr,yaxpr=plot_pr_curve_curve_from_scratch(xtest,[.1,.2,.3,.4,.5,.6])
plt.scatter(xaxpr,yaxpr)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df)
sns.pairplot(df,x_vars=['Math'],y_vars='Bio',height=5,aspect=.7)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import skew
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize']=(12,10)
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
df["GPAAA"]=df["GPAAA"].astype("category")

# %%
df.info()

# %%
sns.pairplot(df,x_vars=["Plus","Math","Bio"],y_vars=["GPAAA"], height=5,aspect=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
x=df[['SLC','Math','Physics']]
y=df[['GPAM']]#dependent

# %%
lr=LinearRegression()
lr.fit(x,y)
print(lr.intercept_)
print(lr.coef_)

# %%
list(zip(['SLC'],lr.coef_))

# %%
sns.heatmap(df.corr(),annot=True)

# %%
#neural network
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize']=(12,10)
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
df["GPAAA"]=df["GPAAA"].astype("category")

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
plt.matshow(x_test[0])

# %%
x_train=x_train/255# normalization
x_test=x_test/255
xtrainf=x_train.reshape(len(x_train),28*28)
xtestf=x_test.reshape(len(x_test),28*28)

# %%
xtrainf.shape

# %%
model=keras.Sequential([
keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(xtrainf,y_train,epochs=5)

# %%
model.evaluate(xtestf,y_test)

# %%
plt.matshow(xtrainf)

# %%
ypred=model.predict(xtestf)
ypred[0]

# %%
#ROC Curve for multiclass classification
#Classifier: Random Forest
#The dataset used in this tutorial is from this paper:
#Morang’a, C.M., Amenga–Etego, L., Bah, S.Y. et al. Machine learning approaches classify clinical malaria outcomes based on haematological parameters. BMC Med 18, 375 (2020). https://doi.org/10.1186/s12916-020-01823-3

# %%
import pandas as pd        
import numpy as np         
import matplotlib.pyplot as plt   
import seaborn as sns

# %%
#read the data with pandas
dataframe=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")

# %%
#find the number of rows and columns in the dataframe
dataframe.shape

# %%
#get the first n rows in the dataframe
dataframe.head(n=5)

# %%
# list the column names
dataframe.columns

# %%
#obtain some information about the data 
#i.e. columns,datatypes,missing values,etc
dataframe.info()

# %%
#we are interested in the columns : 'Clinical_diagnosis' up to 'RBC_dist_width_Percent'
#meaning we will subset the data from column 16 - the last column
subset=dataframe.iloc[:,0:8]

# %%
subset.shape

# %%
subset.info()

# %%
#Check the mising data. We are interested in how many missing data are present in each column
subset.isnull().sum()

# %%
# handling missing values
# drop / remove all rows with missing values
subset.dropna(inplace=True)

# %%
subset.shape
subset.columns

# %%
#Let us get the different malaria outcomes. 
#The outcomes will be our labels/classes in the data
subset['GPAAA'].unique()

# %%
labels=pd.Categorical(subset['GPAAA'])
labels
subset.head()

# %%
#class distribution
subset['GPAAA'].value_counts()

# %%
# plot a bar chat to display the class distribution
subset['GPAAA'].value_counts().plot.bar()

# %%
#descriptive statistics on the data
subset.iloc[:,1:].describe().transpose()

# %%
#check the correlation for the features
subset.corr()

# %%
#lets visualize the correlation matrix using seaborn
sns.heatmap(subset.corr(),cmap='coolwarm')

# %%
# separate the labels/classes from the features/measurement
X=subset.iloc[:,0:6]

y=subset.iloc[:,7:8]
X

# %%
#This is required by scikit learn when dealing with categorical data.
#Lets encode target labels (y) with values between 0 and n_classes-1.
#We will use the LabelEncoder to do this. 
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
label_encoder.fit(y)
y=label_encoder.transform(y)
classes=label_encoder.classes_

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler=MinMaxScaler()
X_train_norm=min_max_scaler.fit_transform(X_train)
X_test_norm=min_max_scaler.fit_transform(X_test)

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,auc

# %%
#This will be done by parsing the training set to a classifier or classifiers Because we are dealing with 3 classes, this becomes a multiclass classification problem. We therefore us the One-vs-the-rest strategy.
#This strategy involves fitting one classifier per class. For each classifier, the class is fitted against all the other classes. Here, we use the Random Forest Classifier
#Random Forest Classifier
#because we are dealing with multiclass data and so, the one versus rest strategy is used.
#learn to predict each class against the other.

RF=OneVsRestClassifier(RandomForestClassifier(max_features=.2))
RF.fit(X_train_norm,y_train)
y_pred =RF.predict(X_test_norm)
pred_prob = RF.predict_proba(X_test_norm)

# %%
#Plot the ROC Curve
classes.shape[0]

# %%
from sklearn.preprocessing import label_binarize
#binarize the y_values
y_test_binarized=label_binarize(y_test,classes=np.unique(y_test))
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}
roc_auc = dict()
n_class = classes.shape[0]
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test_binarized[:,i], pred_prob[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])    
    # plotting    
    plt.plot(fpr[i], tpr[i], linestyle='--', 
             label='%s vs Rest (AUC=%0.2f)'%(classes[i],roc_auc[i]))
plt.plot([0,1],[0,1],'b--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='lower right')
plt.show()

# %%
#Execution time Many model accuracy Lazy
# Import libraries
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
# Load dataset
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
x=df.drop(['GPAM','Pf','Result','Res','pff','GPAAA','Churn'],axis=1).values
df["GPAAA"]=df["GPAAA"].astype("category")
y=df['Pf'].values
# Data split
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=.2,random_state =42)
# Defines and builds the lazyclassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, y_train, y_train)
models_test,predictions_test = clf.fit(X_train, X_test, y_train, y_test)
# Prints the model performance
models_train

# %%
models_train.to_csv("C:\\Users\\Rimal\\Desktop\\models_train.csv",index=True)
#models_train['Accuracy']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\models_train.csv",encoding='latin1')
df.drop(['Balanced Accuracy'],inplace=True,axis=1)
table = pd.pivot_table(data=df,index=['Model','Accuracy','F1 Score','ROC AUC','Time Taken'],values=['Time Taken'], aggfunc=np.mean)
table

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\models_train.csv")
table = pd.pivot_table(data=df,index=['Model','Accuracy','Balanced Accuracy','F1 Score','ROC AUC','Time Taken'],values=['Time Taken'], aggfunc=np.mean)
table
grid_contour = table.groupby(['Model','Accuracy','Balanced Accuracy']).mean()
grid_contour
grid_reset = grid_contour.reset_index()
grid_reset.columns = ['Model','Accuracy','Balanced Accuracy']
grid_pivot = grid_reset.pivot('Model','Accuracy')
grid_pivot
x = grid_pivot.columns.levels[1].values
y = grid_pivot.index.values
z = grid_pivot.values 
import plotly.graph_objects as go
layout = go.Layout(
              xaxis=go.layout.XAxis(
              title=go.layout.xaxis.Title(text='Accuracy')),
             yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Model')) )
fig = go.Figure(data = [go.Contour(z=z, x=x, y=y)], layout=layout )
fig.update_layout(title='Hyperparameter tuning', autosize=False,
                  width=500, height=500,margin=dict(l=65, r=50, b=65, t=90))


fig.show()
import plotly.graph_objects as go
fig = go.Figure(data= [go.Surface(z=z, y=y, x=x)], layout=layout )
fig.update_layout(title='Hyperparameter tuning',
                  scene = dict(
                    xaxis_title='Accuracy',
                    yaxis_title='F1 Score',
                    zaxis_title='ROC AUC'),
                  autosize=False,
                  width=800, height=800,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 5))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x=models_train.index, y="Accuracy", data=models_train)
plt.xticks(rotation=90)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_train.index, x="Accuracy", data=models_train)

# %%
from sklearn import datasets
import pandas as pd
import lazypredict
from lazypredict.Supervised import LazyClassifier
from lazypredict.Supervised import LazyRegressor
from sklearn.datasets import load_breast_cancer
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head()) 
x=df.drop(['GPAAA','GPAM','Result','Res','pff','Churn'],axis=1).values
y=df['Pf'].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =42)
# Defines and builds the lazyclassifier
reg = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None)
models_train,predictions_train = reg.fit(X_train, X_train, y_train, y_train)
models_test,predictions_test = reg.fit(X_train, X_test, y_train, y_test)
# Prints the model performance
models_train

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]
plt.figure(figsize=(10, 5))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x=models_train.index, y="R-Squared", data=models_train)
ax.set(ylim=(0, 1))
plt.xticks(rotation=90)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
models_train["R-Squared"] = [0 if i < 0 else i for i in models_train.iloc[:,0] ]
plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_train.index, x="R-Squared", data=models_train)
ax.set(xlim=(0, 1))

# %%
#K nearestNeighbours for

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
print(df.head()) 
x=df.drop(['GPAAA','GPAM'],axis=1).values
y=df['Pf'].values
x=df.iloc[:,0:7]
y=df.iloc[:,7:8]
df

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=5)
knn=KNeighborsClassifier(n_neighbors=8).fit(x_train,y_train)
ypred=knn.predict(x_test)
metrics.accuracy_score(y_test,ypred)

# %%
k_range=range(1,20)
scores=[]
for k in k_range:
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    scores.append(metrics.accuracy_score(y_test,y_pred))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(k_range,scores)
plt.xlabel("Value in k fro KNN")
plt.ylabel("Teating Accuracy")

# %%
knn=KNeighborsClassifier(n_neighbors=3)# from chart
knn.fit(x_train,y_train)
ypred=knn.predict(x_test)
metrics.accuracy_score(y_test,ypred)

# %%
# cross validation is the techniques which involves reserving a particular sample of the data set on which we do not trainthe model
#later we test the model on this sample before finalizing the model  we researved the fixed sample  different for each model validation

# %%
from sklearn.model_selection import cross_val_score
knn=KNeighborsClassifier(n_neighbors=8)
print(cross_val_score(knn,x,y,cv=10,scoring='accuracy'))
pp=cross_val_score(knn,x,y,cv=10,scoring='accuracy').mean()
pp.mean()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
logreg=LogisticRegression()
logreg.fit(x,y)

# %%
model = LogisticRegression(solver='liblinear', C=10.0, random_state=0)
model.fit(x, y)
# Step 4: Evaluate the model
p_pred = model.predict_proba(x)
y_pred = model.predict(x)
score_ = model.score(x, y)
conf_m = confusion_matrix(y, y_pred)
report = classification_report(y, y_pred)
print("Score is",score_)
print("Score is",conf_m)
print("Score is",report)

# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\Breast.csv")
print(df.head()) 
df=df.dropna(axis=1, how='all')

# %%
print(df.describe().T)# normalized
print(df.isnull().sum())
df=df.rename(columns={'diagnosis':'Label'})

# %%
sns.countplot(x="Label",data=df)

# %%
y=df["Label"].values

# %%
from sklearn.preprocessing import LabelEncoder
labelenocder=LabelEncoder()# m=0 B=1
y=labelenocder.fit_transform(y)

# %%
X=df.drop(labels=['Label',"id"],axis=1)

# %%
from sklearn .preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X)
X=scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=0)#rand

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf=RandomForestClassifier(n_estimators=10,random_state=42)
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
accuracy=accuracy_score(y_test,pred)
print("acccuracy",accuracy*100,"%")
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, pred)
cm
sns.heatmap(cm,annot=True)

# %%
from xgboost import XGBClassifier 
from sklearn.metrics import accuracy_score
model = XGBClassifier()
model.fit(x_train, y_train)
pred=model.predict(x_test)
accuracy=accuracy_score(y_test,pred)
print("acccuracy",accuracy*100,"%")
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, pred)
cm
sns.heatmap(cm,annot=True)

# %%
#counter tree 3D Shape 
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
df.head()
X=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
Y=df['Pf'].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier(max_features=5, n_estimators=100)
rf.fit(X_train, Y_train) #rf.score(X_test, Y_test)
Y_pred = rf.predict(X_test)
print("normal",Y_pred)
acc=accuracy_score(Y_pred, Y_test)#Y_pred, Y_test
print(" acc",acc)
from sklearn.model_selection import GridSearchCV
import numpy as np
max_features_range = np.arange(1,6,1)
n_estimators_range = np.arange(10,210,10)
param_grid = dict(max_features=max_features_range, n_estimators=n_estimators_range)
rf = RandomForestClassifier()
grid = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3)
grid.fit(X_train, Y_train)
print("The best parameters are %s with a score of %0.2f",grid.best_params_, grid.best_score_)
import pandas as pd
grid_results = pd.concat([pd.DataFrame(grid.cv_results_["params"]),pd.DataFrame(grid.cv_results_["mean_test_score"], columns=["Accuracy"])],axis=1)
grid_results.head()
grid_contour = grid_results.groupby(['max_features','n_estimators']).mean()
grid_contour

# %%
grid_reset = grid_contour.reset_index()
grid_reset.columns = ['max_features', 'n_estimators', 'Accuracy']
grid_pivot = grid_reset.pivot('max_features', 'n_estimators')
grid_pivot
x = grid_pivot.columns.levels[1].values
y = grid_pivot.index.values
z = grid_pivot.values

# %%
grid_reset = grid_contour.reset_index()
grid_reset.columns = ['max_features', 'n_estimators', 'Accuracy']
grid_pivot = grid_reset.pivot('max_features', 'n_estimators')
grid_pivot
x = grid_pivot.columns.levels[1].values
y = grid_pivot.index.values
z = grid_pivot.values
import plotly.graph_objects as go
layout = go.Layout(
            xaxis=go.layout.XAxis(
              title=go.layout.xaxis.Title(text='n_estimators')),
             yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='max_features')) )
fig = go.Figure(data = [go.Contour(z=z, x=x, y=y)], layout=layout )
fig.update_layout(title='Hyperparameter tuning', autosize=False,
                  width=500, height=500,margin=dict(l=65, r=50, b=65, t=90))

fig.show()
import plotly.graph_objects as go
fig = go.Figure(data= [go.Surface(z=z, y=y, x=x)], layout=layout )
fig.update_layout(title='Hyperparameter tuning',
                  scene = dict(
                    xaxis_title='n_estimators',
                    yaxis_title='max_features',
                    zaxis_title='Accuracy'),
                  autosize=False,
                  width=800, height=800,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()

# %%
What is ROC curve?
The ROC curve summarizes the prediction performance of a classification model at all classification thresholds. Particularly, the ROC curve plots the False Positive Rate (FPR) on the X-axis and the True Positive Rate (TPR) on the Y-axis.

TPR (Sensitivity)=𝑇𝑃𝑇𝑃+𝐹𝑁
 
FPR (1 - Specificity)=𝐹𝑃𝑇𝑁+𝐹𝑃

# %%
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
import xgboost as xgb
import numpy as np
import pandas as pd
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\homeprice - Copy.csv")
X=df.drop(['GPAM','Pf','Result','GPAAA','Res','pff','Churn'],axis=1).values
Y=df['Pf'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2,random_state=0)
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from lightgbm import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn. ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
rf = RandomForestClassifier(max_features=5, n_estimators=500)
nb = GaussianNB()
knn=KNeighborsClassifier(n_neighbors=8)
dt=DecisionTreeClassifier()
adb=AdaBoostClassifier(n_estimators=200,random_state=1,learning_rate=.01)
xgc=GradientBoostingClassifier(n_estimators=200,random_state=1,learning_rate=.01)
xgf=xgb.XGBClassifier(n_estimators=200,random_state=1,learning_rate=.01)
svm=svm.SVC(kernel='linear', C=1.2, probability=True)
lr=LogisticRegression()
bag=BaggingClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=100,max_samples=0.8, oob_score=True,random_state=0)
lgb=LGBMClassifier(boosting_type='gbdt')
xt=ExtraTreesClassifier(n_estimators=100, criterion='gini')
lda=LinearDiscriminantAnalysis(solver='svd')

lgb.fit(X_train,Y_train)
rf.fit(X_train, Y_train)
nb.fit(X_train, Y_train)
knn.fit(X_train,Y_train)
adb.fit(X_train,Y_train)
xgc.fit(X_train,Y_train)
xgf.fit(X_train,Y_train)
dt.fit(X_train,Y_train)
svm.fit(X_train,Y_train)
lr.fit(X_train,Y_train)
bag.fit(X_train,Y_train)
lgb.fit(X_train,Y_train)
xt.fit(X_train,Y_train)
lda.fit(X_train,Y_train)

# %%
r_probs = [0 for _ in range(len(Y_test))]
rf_probs = rf.predict_proba(X_test)
nb_probs = nb.predict_proba(X_test)
knn_probs=knn.predict_proba(X_test)
adb_probs=adb.predict_proba(X_test)
xgc_probs=xgc.predict_proba(X_test)
xgf_probs=xgf.predict_proba(X_test)
dt_probs=dt.predict_proba(X_test)
svm_probs=svm.predict_proba(X_test)
lr_probs=lr.predict_proba(X_test)
bag_probs=bag.predict_proba(X_test)
lgb_probs=lgb.predict_proba(X_test)
xt_probs=xt.predict_proba(X_test)
lda_probs=lda.predict_proba(X_test)

# %%
rf_probs = rf_probs[:,1]
nb_probs = nb_probs[:,1]
knn_probs=knn_probs[:,1]
adb_probs=adb_probs[:,1]
xgc_probs=xgc_probs[:,1]
xgf_probs=xgf_probs[:,1]
dt_probs=dt_probs[:,1]
svm_probs=svm_probs[:,1]
lr_probs=lr_probs[:,1]
bag_probs=bag_probs[:,1]
lgb_probs=lgb_probs[:,1]
xt_probs=xt_probs[:,1]
lda_probs=lda_probs[:,1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
r_auc = roc_auc_score(Y_test, r_probs)
rf_auc = roc_auc_score(Y_test, rf_probs)
nb_auc = roc_auc_score(Y_test, nb_probs)
knn_auc = roc_auc_score(Y_test, knn_probs)
adb_auc = roc_auc_score(Y_test, adb_probs)
xgc_auc = roc_auc_score(Y_test, xgc_probs)
xgf_auc = roc_auc_score(Y_test,xgf_probs)
dt_auc = roc_auc_score(Y_test,dt_probs)
svm_auc = roc_auc_score(Y_test,svm_probs)
lr_auc = roc_auc_score(Y_test,lr_probs)
bag_auc = roc_auc_score(Y_test,bag_probs)
lgb_auc = roc_auc_score(Y_test,lgb_probs)
xt_auc = roc_auc_score(Y_test,xt_probs)
lda_auc = roc_auc_score(Y_test,lda_probs)

# %%
print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Random Forest: AUROC = %.3f' % (rf_auc))
print('Naive Bayes: AUROC = %.3f' % (nb_auc))
print('Knearest: AUROC = %.3f' % (knn_auc))
print('AdaBoost: AUROC = %.3f' % (adb_auc))
print('XgBoost: AUROC = %.3f' % (xgc_auc))
print('XGF: AUROC = %.3f' % (xgf_auc))
print('Decison Tree: AUROC = %.3f' % (dt_auc))
print('Support Vector: AUROC = %.3f' % (svm_auc))
print('Linear Reg: AUROC = %.3f' % (lr_auc))
print('Bagging: AUROC = %.3f' % (bag_auc))
print('LGB Classifi: AUROC = %.3f' % (lgb_auc))
print('ExtraTree: AUROC = %.3f' % (xt_auc))
print('Linear discri: AUROC = %.3f' % (lda_auc))

# %%
r_fpr, r_tpr, _ = roc_curve(Y_test, r_probs)
rf_fpr, rf_tpr, _ = roc_curve(Y_test, rf_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, nb_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, knn_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, adb_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, xgc_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, xgf_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, dt_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, svm_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, lr_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, bag_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, lgb_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, xt_probs)
nb_fpr, nb_tpr, _ = roc_curve(Y_test, lda_probs)

# %%
plt.figure(figsize=(10,6))
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(rf_fpr, rf_tpr, marker='.', label='Random Forest (AUROC = %0.3f)' % rf_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Naive Bayes (AUROC = %0.3f)' % nb_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Knn (AUROC = %0.3f)' % knn_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='ADB (AUROC = %0.3f)' % adb_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='XGB (AUROC = %0.3f)' % xgc_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='XGF (AUROC = %0.3f)' % xgf_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='DecisionTree (AUROC = %0.3f)' % dt_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Support Vector (AUROC = %0.3f)' % svm_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Linear Regress (AUROC = %0.3f)' % lr_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Bagging (AUROC = %0.3f)' % bag_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='LGB (AUROC = %0.3f)' % lgb_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Extra Tree(AUROC = %0.3f)' % xt_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Linear Discri (AUROC = %0.3f)' % lda_auc)
# Title
plt.title('ROC Plot')
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() #
plt.show()

# %%
dataset = pd.read_csv('C:\\Users\\Rimal\\Desktop\\diabetes.csv')
X = dataset.iloc[:, 1:9].values
y = dataset.iloc[:, 9:10].values

# %%
# # Ensemble Learning
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn. ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn import tree  
from sklearn import metrics 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
dataset = pd.read_csv('C:\\Users\\Rimal\\Desktop\\diabetes_.csv')
X = dataset.iloc[:, 1:9].values
y = dataset.iloc[:, 9:10].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)
# accuracy on X_test
print("Knn: ",knn.score(X_test,y_test))
# Create Decision Tree classifer object
model = DecisionTreeClassifier(random_state=0)
# Train Decision Tree Classifer
model = model.fit(X_train,y_train)
#evaluate
print("Decision Tree Score: ",model.score(X_test,y_test))
# Create RF classifer 
rf = RandomForestClassifier(n_estimators=100)
# Train 
rf = rf.fit(X_train,y_train)
print("Random Forest Score: ",rf.score(X_test,y_test))
bag = BaggingClassifier(DecisionTreeClassifier(), n_estimators = 10)
# Train 
bag = bag.fit(X_train,y_train)
print("Bagging  Score: ",bag.score(X_test,y_test))
boost = AdaBoostClassifier(DecisionTreeClassifier(),n_estimators = 10, learning_rate = 1)
# Train 
boost = boost.fit(X_train,y_train)
print("Boosting Score: ",boost.score(X_test,y_test))

# Voting Classifier - Multiple Model Ensemble 
lr = LogisticRegression()
dt = DecisionTreeClassifier()
svm = SVC(kernel = 'poly', degree = 2 )

evc = VotingClassifier( estimators= [('lr',lr),('dt',dt),('svm',svm),('knn',knn)], voting = 'hard')

# Train 
evc = evc.fit(X_train,y_train)

print("LR DT SVM Knn: ",evc.score(X_test,y_test))

# %%
#H20      H20

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.metrics import classification_report
import xgboost as xgb
import numpy as np
import pandas as pd
import h2o

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; OpenJDK 64-Bit Server VM JBR-11.0.13.7-1751.21-jcef (build 11.0.13+7-b1751.21, mixed mode)
#   Starting server from C:\ProgramData\Anaconda3\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\Rimal\AppData\Local\Temp\tmptsms1wl3
#   JVM stdout: C:\Users\Rimal\AppData\Local\Temp\tmptsms1wl3\h2o_Rimal_started_from_python.out
#   JVM stderr: C:\Users\Rimal\AppData\Local\Temp\tmptsms1wl3\h2o_Rimal_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         13 secs
# H2O_cluster_timezone:       Asia/Kathmandu
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.4
# H2O_cluster_version_age:    18 days
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\Heart.csv")
#df = pd.read_csv('https://raw.githubusercontent.com/kb22/Heart-Disease-Prediction/master/dataset.csv')
df.head()
#churn_df = h2o.import_file('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv')
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal target
# 0      3  0.0       fixed     No
# 1      2  3.0      normal    Yes
# 2      2  2.0  reversable    Yes
# 3      3  0.0      normal     No
# 4      1  0.0      normal     No

# %%
churn_df=h2o.H2OFrame(df)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
churn_df.describe()
churn_df.head()
# Out:
# Rows:303
# Cols:14
#          Age                Sex                 ChestPain     RestBP              Chol                Fbs                  RestECG             MaxHR               ExAng                Oldpeak             Slope               Ca                  Thal        target
# -------  -----------------  ------------------  ------------  ------------------  ------------------  -------------------  ------------------  ------------------  -------------------  ------------------  ------------------  ------------------  ----------  --------
# type     int                int                 enum          int                 int                 int                  int                 int                 int                  real                int                 int                 enum        enum
# ...

# %%
churn_train,churn_test,churn_valid = churn_df.split_frame(ratios=[.7, .15])

# %%
y = "target"
x = churn_df.columns
x.remove(y)

# %%
import h2o
from h2o.automl import H2OAutoML
aml = H2OAutoML(max_models =10, seed = 10, exclude_algos = ["StackedEnsemble", "DeepLearning"], verbosity="info", nfolds = 3)
#aml = H2OAutoML(max_runtime_secs = 30, sort_metric = "logloss",exclude_algos = ["DeepLearning", "DRF"])

# %%
aml.train(x = x, y = y, training_frame = churn_train, validation_frame=churn_valid)
# Out:
# AutoML progress: |
# 09:25:45.319: Project: AutoML_1_20230124_92545
# 09:25:45.324: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 09:25:45.327: Setting stopping tolerance adaptively based on the training frame: 0.05
# 09:25:45.328: Build control seed: 10
# 09:25:45.332: training frame: Frame key: AutoML_1_20230124_92545_training_py_3_sid_8fe1    cols: 14    rows: 215  chunks: 1    size: 5485  checksum: -6323966155402328388
# 09:25:45.333: validation frame: Frame key: py_5_sid_8fe1    cols: 14    rows: 38  chunks: 1    size: 3450  checksum: -188240375143522600
# 09:25:45.334: leaderboard frame: NULL
# 09:25:45.335: blending frame: NULL
# 09:25:45.337: response column: target
# 09:25:45.338: fold column: null
# 09:25:45.339: weights column: null
# ...

# %%
lb = aml.leaderboard

# %%
lb.head()
# Out:
# model_id                                         auc    logloss     aucpr    mean_per_class_error      rmse       mse
# ------------------------------------------  --------  ---------  --------  ----------------------  --------  --------
# GLM_1_AutoML_1_20230124_92545               0.883365   0.413022  0.888016                0.179364  0.362267  0.131237
# GBM_grid_1_AutoML_1_20230124_92545_model_1  0.87891    0.432016  0.87272                 0.171239  0.369131  0.136258
# GBM_4_AutoML_1_20230124_92545               0.877861   0.427162  0.878006                0.204438  0.372526  0.138775
# GBM_grid_1_AutoML_1_20230124_92545_model_3  0.87725    0.431612  0.886432                0.172156  0.369015  0.136172
# GBM_2_AutoML_1_20230124_92545               0.87725    0.42383   0.890634                0.172724  0.365861  0.133854
# DRF_1_AutoML_1_20230124_92545               0.875983   0.43181   0.878593                0.19426   0.376091  0.141445
# ...

# %%
churn_pred=aml.leader.predict(churn_test)
# Out:
# glm prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
churn_pred.head()
# Out:
# predict            No        Yes
# ---------  ----------  ---------
# Yes        0.00727811  0.992722
# Yes        0.458404    0.541596
# No         0.602711    0.397289
# Yes        0.198517    0.801483
# Yes        0.190858    0.809142
# No         0.796921    0.203079
# Yes        0.0424957   0.957504
# No         0.915103    0.0848965
# Yes        0.457086    0.542914
# Yes        0.387557    0.612443
# [10 rows x 3 columns]

# %%
aml.leader.model_performance(churn_test)
# Out:
# ModelMetricsBinomialGLM: glm
# ** Reported on test data. **
#
# MSE: 0.0894987663030722
# RMSE: 0.29916344412891127
# LogLoss: 0.3076777344627562
# AUC: 0.9500805152979065
# AUCPR: 0.9306672819622879
# Gini: 0.900161030595813
# Null degrees of freedom: 49
# Residual degrees of freedom: 30
# Null deviance: 69.0101280804648
# Residual deviance: 30.767773446275623
# AIC: 70.76777344627563
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.5406856331978203
#        No    Yes    Error    Rate
# -----  ----  -----  -------  ----------
# No     25    2      0.0741   (2.0/27.0)
# Yes    2     21     0.087    (2.0/23.0)
# Total  27    23     0.08     (4.0/50.0)
#
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.540686     0.913043  22
# max f2                       0.397289     0.92437   26
# ...

# %%
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
#se = h2o.get_model([mid for mid in model_ids if "StackedEnsemble_AllModels" in mid][0])
#metalearner = h2o.get_model(se.metalearner()['name'])

# %%
model_ids
# Out:
# ['GLM_1_AutoML_1_20230124_92545',
#  'GBM_grid_1_AutoML_1_20230124_92545_model_1',
#  'GBM_4_AutoML_1_20230124_92545',
#  'GBM_grid_1_AutoML_1_20230124_92545_model_3',
#  'GBM_2_AutoML_1_20230124_92545',
#  'DRF_1_AutoML_1_20230124_92545',
#  'GBM_3_AutoML_1_20230124_92545',
#  'GBM_grid_1_AutoML_1_20230124_92545_model_2',
#  'GBM_5_AutoML_1_20230124_92545',
#  'XRT_1_AutoML_1_20230124_92545']

# %%
h2o.get_model([mid for mid in model_ids if "GBM" in mid][0])
# Out:
# Model Details
# ...
# H2OGradientBoostingEstimator : Gradient Boosting Machine
# Model Key: GBM_grid_1_AutoML_1_20230124_92545_model_1
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     50                 50                          5498                   2            3            2.5           3             5             4.08
#
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.0964909939630312
# RMSE: 0.31062999527256085
# LogLoss: 0.32458917838874857
# Mean Per-Class Error: 0.12746811113052595
# AUC: 0.9483662414817403
# AUCPR: 0.9413459089023566
# Gini: 0.8967324829634806
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.32626317921200165
# ...

# %%
h2o.get_model([mid for mid in model_ids if "DRF" in mid][0])
# Out:
# Model Details
# ...
# H2ORandomForestEstimator : Distributed Random Forest
# Model Key: DRF_1_AutoML_1_20230124_92545
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     26                 26                          13548                  6            12           8.88462       27            45            36.6923
#
# ModelMetricsBinomial: drf
# ** Reported on train data. **
#
# MSE: 0.15370664072490212
# RMSE: 0.39205438490712247
# LogLoss: 0.5989120190999152
# Mean Per-Class Error: 0.24165647387733705
# AUC: 0.8554080027957365
# AUCPR: 0.8541040556880305
# Gini: 0.710816005591473
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.36363636363636365
#        No    Yes    Error    Rate
# ...

# %%
h2o.get_model([mid for mid in model_ids if "XRT" in mid][0])
# Out:
# Model Details
# ...
# H2ORandomForestEstimator : Distributed Random Forest
# Model Key: XRT_1_AutoML_1_20230124_92545
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     35                 35                          19674                  9            18           11.1714       26            52            40.1143
#
# ModelMetricsBinomial: drf
# ** Reported on train data. **
#
# MSE: 0.15005770088313353
# RMSE: 0.38737281897822096
# LogLoss: 0.6044203686088733
# Mean Per-Class Error: 0.21955268215970647
# AUC: 0.8637952123012407
# AUCPR: 0.840580573446869
# Gini: 0.7275904246024814
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.364080548286438
#        No    Yes    Error    Rate
# ...

# %%
out=h2o.get_model([mid for mid in model_ids if "GLM" in mid][0])
out
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator : Generalized Linear Modeling
# Model Key: GLM_1_AutoML_1_20230124_92545
#
#
# GLM Model: summary
#     family    link    regularization              lambda_search                                                                  number_of_predictors_total    number_of_active_predictors    number_of_iterations    training_frame
# --  --------  ------  --------------------------  -----------------------------------------------------------------------------  ----------------------------  -----------------------------  ----------------------  ----------------------------------------------
#     binomial  logit   Ridge ( lambda = 0.01674 )  nlambda = 30, lambda.max = 24.903, lambda.min = 0.01674, lambda.1se = 0.05964  19                            19                             48                      AutoML_1_20230124_92545_training_py_3_sid_8fe1
#
# ModelMetricsBinomialGLM: glm
# ** Reported on train data. **
#
# MSE: 0.11020547950432524
# ...

# %%
outgbm = h2o.get_model("GBM_grid_1_AutoML_1_20230123_83743_model_1")
outgbm.confusion_matrix()
# Out:
# ---------------------------------------------------------------------------
# H2OResponseError                          Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 outgbm = h2o.get_model("GBM_grid_1_AutoML_1_20230123_83743_model_1")
#       2 outgbm.confusion_matrix()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\h2o\h2o.py:1091, in get_model(model_id)
#    1064 """
#    1065 Load a model from the server.
#    1066
#    (...)
#    1088 >>> model2 = h2o.get_model(model.model_id)
#    1089 """
#    1090 assert_is_type(model_id, str)
# -> 1091 model_json = api("GET /3/Models/%s" % model_id)["models"][0]
#    1092 algo = model_json["algo"]
#    1093 # still some special handling for AutoEncoder: would be cleaner if we could get rid of this
#
# File C:\ProgramData\Anaconda3\lib\site-packages\h2o\h2o.py:124, in api(endpoint, data, json, filename, save_to)
#     122 # type checks are performed in H2OConnection class
#     123 _check_connection()
# ...

# %%
model_ids
# Out:
# ['GLM_1_AutoML_1_20230124_92545',
#  'GBM_grid_1_AutoML_1_20230124_92545_model_1',
#  'GBM_4_AutoML_1_20230124_92545',
#  'GBM_grid_1_AutoML_1_20230124_92545_model_3',
#  'GBM_2_AutoML_1_20230124_92545',
#  'DRF_1_AutoML_1_20230124_92545',
#  'GBM_3_AutoML_1_20230124_92545',
#  'GBM_grid_1_AutoML_1_20230124_92545_model_2',
#  'GBM_5_AutoML_1_20230124_92545',
#  'XRT_1_AutoML_1_20230124_92545']

# %%
i = 0
while i < len(model_ids):
    out = h2o.get_model(model_ids[i])
    out.varimp_plot()
    i = i + 1

# %%
df.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD target
# 0      3  0.0       fixed   No     No
# 1      2  3.0      normal  Yes    Yes
# 2      2  2.0  reversable  Yes    Yes
# 3      3  0.0      normal   No     No
# 4      1  0.0      normal   No     No

# %%
df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\Heart.csv")
x=df.drop(['target'],axis=1).values
df['target'] = df['target'].asfactor()
y=df['target'].values
from sklearn.model_selection import train_test_split
train,test,train,test= train_test_split(x,y,test_size=0.2,random_state=0)#rand
# For binary classification, response should be a factor

# Train AutoML, omitting DeepLearning and DRF
aml = H2OAutoML(max_runtime_secs = 30, sort_metric = "logloss",
                exclude_algos = ["DeepLearning", "DRF"])
aml.train(x = x, y = y, training_frame = train)

# View the AutoML Leaderboard
lb = aml.leaderboard
lb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       1 df=pd.read_csv("C:\\Users\\Rimal\\Desktop\\Heart.csv")
#       2 x=df.drop(['target'],axis=1).values
# ----> 3 df['target'] = df['target'].asfactor()
#       4 y=df['target'].values
#       5 from sklearn.model_selection import train_test_split
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'asfactor'

# %%
aml.leader.download_mojo(path = "./")

# %%
#new Stacked Ensembles
#Ensemble machine learning methods use multiple learning algorithms to obtain better predictive performance than the ones that could be obtained from any of the constituent learning algorithms. Many of the popular modern machine learning algorithms are actually ensembles. For example, Random Forest and Gradient Boosting Machine (GBM) are both ensemble learners. Both bagging (e.g., Random Forest) and boosting (e.g., GBM) are methods for ensembling that take a collection of weak learners (e.g., decision tree) and form a single, strong learner
#The current version of AutoML trains and cross-validates the following model: GLMs, a Random Forest, an Extremely-Randomized Forest, a random grid of Gradient Boosting Machines (GBMs), XGBoosts, a random grid of Deep Neural Nets, and a Stacked Ensemble of all the models. If you would like to know more details about the models trained by AutoML, please visit Which models are trained in the AutoML process? under the FAQ of the AutoML Documentation section. To see how H2O AutoML performs compared to other AutoML algorithms, please look at An Open Source AutoML Benchmark

# %%
import h2o
import matplotlib as plt
# %matplotlib inline
from h2o.automl import H2OAutoML

# %%
import os
import h2o
startup  = '/home/h2o/bin/aquarium_startup'
shutdown = '/home/h2o/bin/aquarium_stop'
if os.path.exists(startup):
    os.system(startup)
    local_url = 'http://localhost:54321/h2o'
    aquarium = True
else:
    local_url = 'http://localhost:54321'
    aquarium = False

# %%
h2o.init(url=local_url)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         19 mins 07 secs
# H2O_cluster_timezone:       Asia/Kathmandu
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.4
# H2O_cluster_version_age:    17 days
# H2O_cluster_name:           H2O_from_python_Rimal_mc74wi
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.394 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.12 final
# --------------------------  -----------------------------

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         19 mins 24 secs
# H2O_cluster_timezone:       Asia/Kathmandu
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.4
# H2O_cluster_version_age:    17 days
# H2O_cluster_name:           H2O_from_python_Rimal_mc74wi
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.394 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.12 final
# --------------------------  -----------------------------

# %%
import h2o
h2o.init()
hear = "https://raw.githubusercontent.com/Bakar31/Heart-Disease/master/data/heart.csv"
heart = h2o.import_file(path=hear)
heart.head()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         1 hour 12 mins
# H2O_cluster_timezone:       Asia/Kathmandu
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.4
# H2O_cluster_version_age:    17 days
# H2O_cluster_name:           H2O_from_python_Rimal_mc74wi
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.393 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.12 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Bakar31/Heart-Disease/master/data/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
titanic = h2o.import_file("https://s3.amazonaws.com/h2o-public-test-data/smalldata/gbm_test/titanic.csv")
predictors = ["home.dest", "cabin", "embarked"]
response = "survived"
titanic[response] = titanic[response].asfactor()
fold_col = "kfold_column"
titanic[fold_col] = titanic.kfold_column(n_folds=5, seed=1234)
titanic_te = H2OTargetEncoderEstimator(data_leakage_handling="leave_one_out",
                                       inflection_point=35,
                                       smoothing=25,
                                       blending=True,
                                       seed=1234)
titanic_te.train(x=predictors,
                 y=response,
                 training_frame=titanic)
transformed = titanic_te.transform(frame=titanic)

titanic = h2o.import_file("https://s3.amazonaws.com/h2o-public-test-data/smalldata/gbm_test/titanic.csv")
titanic['survived'] = titanic['survived'].asfactor()
predictors = titanic.columns
response = 'survived'
train, valid = titanic.split_frame(ratios=[.8],
                                   seed=1234)
titanic_xgb = H2OXGBoostEstimator(keep_cross_validation_models=True,
                                  nfolds=5 ,
                                  seed=1234)
titanic_xgb.train(x=predictors,
                  y=response,
                  training_frame=train)
titanic_xgb.cross_validation_models()

# %%
df.head()
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 df["target"].table()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'table'

# %%
df["target"].hist()
# Out:
# <AxesSubplot:>

# %%
train, test = df.split_frame([0.8], seed=623)
print("train:%d test:%d" % (train.nrows, test.nrows))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 train, test = df.split_frame([0.8], seed=623)
#       2 print("train:%d test:%d" % (train.nrows, test.nrows))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'split_frame'

# %%
y = "DELINQUENT"
ignore = ["DELINQUENT", "PREPAID", "PREPAYMENT_PENALTY_MORTGAGE_FLAG", "PRODUCT_TYPE"] 
x = list(set(train.names) - set(ignore))

# %%
H2OAutoML(nfolds=5, max_runtime_secs=3600, max_models=None,stopping_metric='AUTO', stopping_tolerance=None, stopping_rounds=3, seed=None, project_name=None)

# %%
aml = H2OAutoML(max_models=20, max_runtime_secs_per_model=5, seed=623, project_name='classification',balance_classes=True, class_sampling_factors=[0.5,1.25])
# %time aml.train(x=x, y=y, training_frame=train)

# %%
lb = aml.leaderboard
lb.head(rows=lb.nrows)

# %%
from h2o.automl import get_leaderboard
lb2 = get_leaderboard(aml, extra_columns='ALL')
lb2.head(rows=lb2.nrows)

# %%
# Get model ids for all models in the AutoML Leaderboard
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])

# Get the "All Models" Stacked Ensemble model
se = h2o.get_model([mid for mid in model_ids if "StackedEnsemble_BestOfFamily" in mid][0])

# Get the Stacked Ensemble metalearner model
metalearner = h2o.get_model(se.metalearner()['name'])
metalearner.coef()

# %%
metalearner.std_coef_plot()

# %%
aml.leader.model_performance(test_data=test)

# %%
# %matplotlib inline
aml.leader.model_performance(test_data=test).plot()

# %%
aml.predict(test)

# %%
m = aml.get_best_model()
# Get the best model using a non-default metric
m = aml.get_best_model(criterion="logloss")

# Get the best XGBoost model using default sort metric
xgb = aml.get_best_model(algorithm="xgboost")

# Get the best XGBoost model, ranked by logloss
xgb = aml.get_best_model(algorithm="xgboost", criterion="logloss")

# %%
#H2O AutoML Regression Problem
y_reg = "ORIGINAL_INTEREST_RATE"

ignore_reg = ["ORIGINAL_INTEREST_RATE", "FIRST_PAYMENT_DATE", "MATURITY_DATE", "MORTGAGE_INSURANCE_PERCENTAGE", "PREPAYMENT_PENALTY_MORTGAGE_FLAG", "LOAN_SEQUENCE_NUMBER", "PREPAID", "DELINQUENT", "PRODUCT_TYPE"] 

x_reg = list(set(train.names) - set(ignore_reg))

# %%
aml = H2OAutoML(max_models = 20, 
                max_runtime_secs_per_model=10, 
                seed=623, 
                project_name='regression', 
                stopping_metric="RMSE", 
                sort_metric="RMSE")

# %time 
aml.train(x=x_reg, y=y_reg, training_frame=train)

# %%
lb = aml.leaderboard
lb.head(rows=lb.nrows)

# %%
# Get model ids for all models in the AutoML Leaderboard
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
# Get the top GBM model
gbm=h2o.get_model("GBM_grid_1_AutoML_4_20230121_121009_model_3")

# %%
model_ids

# %%
xgb = h2o.get_model("XRT_1_AutoML_4_20230121_121009")

# %%
print("ntrees = ", gbm.params['ntrees'])
print("max depth = ", gbm.params['max_depth'])
print("learn rate = ", gbm.params['learn_rate'])
print("sample rate = ", gbm.params['sample_rate'])

# %%
gbm

# %%
gbm.model_performance(test_data=test)

# %%
aml.leader.model_performance(test_data=test)

# %%
pred = gbm.predict(test)
pred = pred.cbind(test['ORIGINAL_INTEREST_RATE'])
pred.head()

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
prostate = h2o.import_file("http://s3.amazonaws.com/h2o-public-test-data/smalldata/prostate/prostate.csv.zip")
prostate[2] = prostate[2].asfactor()
prostate[4] = prostate[4].asfactor()
prostate[5] = prostate[5].asfactor()
prostate[8] = prostate[8].asfactor()
predictors = ["AGE","RACE","DPROS","DCAPS","PSA","VOL","GLEASON"]
response = "CAPSULE"
train, valid = prostate.split_frame(ratios=[.8],seed=1234)
pros_glm = H2OGeneralizedLinearEstimator(family="binomial")
pros_glm.train(x = predictors,
               y = response,
               training_frame = train,
               validation_frame = valid)
pros_glm.aic()

# %%
aml.leader.model_performance(test_data=test).plot()

# %%
#heart disease Five model accuracy

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
#df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv')
df = pd.read_csv('https://raw.githubusercontent.com/kb22/Heart-Disease-Prediction/master/dataset.csv')
df.head()
ohe = OneHotEncoder(categories='auto')
feature_arr = ohe.fit_transform(df[['sex','cp','fbs','restecg','exang','slope','thal','ca']]).toarray()
feature_labels = ohe.get_feature_names()
feature_labels = np.array(feature_labels).ravel()
features = pd.DataFrame(feature_arr, columns=feature_labels)
features.head()
features.rename(columns = {'x0_0':'M','x0_1':'F','x1_0':'typical angina','x1_1':'atypical angina','x1_2':'non-anginal pain','x1_3':'asymptomatic','x2_0':'normal','x2_1':'abnormal','x3_0':'having ST','x3_1':'normal','x3_2':'abnormal','x4_0':'Yes','x4_1':'No','x5_0':'upsloping','x5_1':'flate','x5_2':'down','x6_0':'Normal','x6_1':'fixed defect','x6_2':'reversable defect','x6_3':'non','x7_0':'Ca0','x7_1':'Ca1','x7_2':'ca2','x7_3':'Ca3','x7_4':'Ca4'}, inplace = True)
final=pd.concat([df,features],axis=1)
final.head()
final1=pd.DataFrame(final)
final2=final1.drop(['target','sex','cp','fbs','restecg','exang','slope','thal','ca','Ca4'],axis=1)
final2.head()
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
final2[['age', 'trestbps', 'chol', 'thalach', 'oldpeak','M', 'F',
       'typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic',
       'normal', 'abnormal', 'having ST', 'normal', 'abnormal', 'Yes', 'No',
       'upsloping', 'flate', 'down', 'Normal', 'fixed defect',
       'reversable defect', 'non', 'Ca0', 'Ca1', 'ca2', 'Ca3']] = StandardScaler().fit_transform(final2[['age', 'trestbps', 'chol', 'thalach', 'oldpeak','M', 'F',
       'typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic',
       'normal', 'abnormal', 'having ST', 'normal', 'abnormal', 'Yes', 'No',
       'upsloping', 'flate', 'down', 'Normal', 'fixed defect',
       'reversable defect', 'non', 'Ca0', 'Ca1', 'ca2', 'Ca3']])
final2.head()
df = pd.read_csv('https://raw.githubusercontent.com/kb22/Heart-Disease-Prediction/master/dataset.csv')
final3=pd.concat([final2,df['target']],axis=1)
final3.head()
final3=pd.DataFrame(final3)
final3.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#         age  trestbps      chol   thalach   oldpeak         M         F  \
# 0  0.952197  0.763956 -0.256334  0.015443  1.087338 -0.681005  0.681005
# 1 -1.915313 -0.092738  0.072199  1.633471  2.122573 -0.681005  0.681005
# 2 -1.474158 -0.092738 -0.816773  0.977514  0.310912  1.468418 -1.468418
# 3  0.180175 -0.663867 -0.198357  1.239897 -0.206705 -0.681005  0.681005
# 4  0.290464 -0.663867  2.082050  0.583939 -0.379244  1.468418 -1.468418
#
#    typical angina  atypical angina  non-anginal pain  ...      down    Normal  \
# 0       -0.945384        -0.444554         -0.634648  ... -0.939142 -0.081514
# 1       -0.945384        -0.444554          1.575677  ... -0.939142 -0.081514
# ...

# %%
X=final3.drop(['non','target'],axis=1)
Y=final3.target
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify = Y, random_state=3)
print(X.shape, X_train.shape, X_test.shape)
print(Y.shape, Y_train.shape, Y_test.shape)
from sklearn.model_selection import train_test_split
XTrain, XTest, yTrain, yTest = train_test_split(X, Y, test_size=0.3, random_state=0)
# Out:
# (303, 28) (242, 28) (61, 28)
# (303,) (242,) (61,)

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
sns.clustermap(df.corr(),annot=True)

# %%
from matplotlib import pyplot as plt
df.hist()
plt.show()

# %%
import seaborn as sns
plt.subplots(3,3,figsize=(15,15))

# Plot density function for each variable
for idx, col in enumerate(df.columns):
    ax = plt.subplot(3,3,idx+1)
    ax.yaxis.set_ticklabels([])
    sns.distplot(df.loc[df.target==0][col],hist=False,axlabel=False,kde_kws={'linestyle':'-','color':'black',
                                                                              'label':"No Diabetes"})
    sns.distplot(df.loc[df.target==1][col],hist=False,axlabel=False,kde_kws={'linestyle':'--','color':'black',
                                                                              'label':"Diabetes"})
    ax.set_title(col)

plt.subplot(3,3,9).set_visible(False)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(XTrain,yTrain)
yPred = classifier.predict(XTest)
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("Logistic Regression :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Logistic Regression :
# Accuracy =  0.8351648351648352
# Mean Squared Error: 0.16483516483516483
# R score: 0.3399419729206965
# Mean Absolute Error: 0.16483516483516483

# %%
from sklearn.tree import DecisionTreeClassifier as DT
classifier = DT(criterion='entropy', random_state=0)
classifier.fit(XTrain,yTrain)
yPred = classifier.predict(XTest)
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("Decision Tree Classifier :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Decision Tree Classifier :
# Accuracy =  0.7582417582417582
# Mean Squared Error: 0.24175824175824176
# R score: 0.03191489361702149
# Mean Absolute Error: 0.24175824175824176

# %%
from sklearn.linear_model import Perceptron
classifier = Perceptron(tol=1e-3, random_state=0)
classifier.fit(XTrain,yTrain)
yPred = classifier.predict(XTest)
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("Perceptron :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Perceptron :
# Accuracy =  0.7252747252747253
# Mean Squared Error: 0.27472527472527475
# R score: -0.10009671179883917
# Mean Absolute Error: 0.27472527472527475

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
classifier.fit(XTrain,yTrain)
yPred = classifier.predict(XTest)
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("K Nearest Neighbors :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# K Nearest Neighbors :
# Accuracy =  0.8131868131868132
# Mean Squared Error: 0.18681318681318682
# R score: 0.2519342359767893
# Mean Absolute Error: 0.18681318681318682

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='linear',random_state=0)
classifier.fit(XTrain,yTrain)
yPred = classifier.predict(XTest)
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("Support Vector Machine :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Support Vector Machine :
# Accuracy =  0.8461538461538461
# Mean Squared Error: 0.15384615384615385
# R score: 0.38394584139265
# Mean Absolute Error: 0.15384615384615385

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(XTrain,yTrain)
yPred = classifier.predict(XTest)
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("Gaussian Naive Bayes :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Gaussian Naive Bayes :
# Accuracy =  0.7692307692307693
# Mean Squared Error: 0.23076923076923078
# R score: 0.07591876208897508
# Mean Absolute Error: 0.23076923076923078

# %%
from sklearn.ensemble import RandomForestClassifier as RF
classifier = RF(n_estimators=10, criterion='entropy', random_state=0)
classifier.fit(XTrain,yTrain)
yPred = classifier.predict(XTest)
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("Random Forest Classifier :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Random Forest Classifier :
# Accuracy =  0.8021978021978022
# Mean Squared Error: 0.1978021978021978
# R score: 0.20793036750483573
# Mean Absolute Error: 0.1978021978021978

# %%
from keras.models import Sequential
from keras.layers import Dense
#Initialising ANN
classifier = Sequential()
#Adding the first hidden layer or the input layer
classifier.add(Dense(activation='relu',
                     kernel_initializer='uniform',
                     input_dim=28,
                     units=12))
#Adding the second hidden layer
classifier.add(Dense(activation='relu',
                     kernel_initializer='uniform',
                     units=12))
#Adding the output layer
classifier.add(Dense(activation='sigmoid',
                     kernel_initializer='uniform',
                     units=1))
#Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
print(classifier.summary())
#Fitting the ANN
history = classifier.fit(XTrain, yTrain, batch_size=5, epochs=20, verbose=1)
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'],'green')
plt.plot(history.history['loss'],'red')
plt.title('Model Accuracy-Loss')
plt.xlabel('Epoch')
plt.legend(['Accuracy','Loss'])
plt.show()
#Predicting the Test set Results
yPred = classifier.predict(XTest)
yPred = (yPred>0.5) #Since output is probability
mse = mean_squared_error(yTest,yPred)
r = r2_score(yTest,yPred)
mae = mean_absolute_error(yTest,yPred)
accuracy = accuracy_score(yTest,yPred)
print("Artificial Neural Network Classifier :")
print("Accuracy = ", accuracy)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                348
#
#  dense_1 (Dense)             (None, 12)                156
#
#  dense_2 (Dense)             (None, 1)                 13
#
# ...
# Total params: 517
# Trainable params: 517
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 43/43 [==============================] - 7s 8ms/step - loss: 0.6911 - accuracy: 0.5566
# Epoch 2/20
# 43/43 [==============================] - 0s 8ms/step - loss: 0.6603 - accuracy: 0.5566
# Epoch 3/20
# 43/43 [==============================] - 0s 8ms/step - loss: 0.5594 - accuracy: 0.5566
# Epoch 4/20
# 43/43 [==============================] - 0s 9ms/step - loss: 0.5012 - accuracy: 0.6981
# Epoch 5/20
# 43/43 [==============================] - 0s 9ms/step - loss: 0.4868 - accuracy: 0.8868
# ...

# %%
from prettytable import PrettyTable
table = PrettyTable()
table.field_names = ["Model","Accuracy", "Mean Squared Error", "R² score","Mean Absolute Error"]
models = [
    LogisticRegression(),
    KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski'),
    SVC(kernel='linear',random_state=0),
    GaussianNB(),
    DT(criterion='entropy', random_state=0),
    RF(n_estimators=10, criterion='entropy', random_state=0),
    Perceptron(tol=1e-3, random_state=0)]
for model in models:
    model.fit(XTrain, yTrain)
    yPred = model.predict(XTest)
    accuracy = accuracy_score(yTest,yPred)
    mse = mean_squared_error(yTest,yPred)
    r = r2_score(yTest,yPred)
    mae = mean_absolute_error(yTest,yPred)
    table.add_row([type(model).__name__, format(accuracy, '.3f'),format(mse, '.3f'),format(r, '.3f'),format(mae, '.3f')])
    
table.add_row(["Artificial Neural Network Classifier",0.954 ,0.045,0.817,0.045])
print(table)
# Out:
# +--------------------------------------+----------+--------------------+----------+---------------------+
# |                Model                 | Accuracy | Mean Squared Error | R² score | Mean Absolute Error |
# +--------------------------------------+----------+--------------------+----------+---------------------+
# |          LogisticRegression          |  0.835   |       0.165        |  0.340   |        0.165        |
# |         KNeighborsClassifier         |  0.813   |       0.187        |  0.252   |        0.187        |
# |                 SVC                  |  0.846   |       0.154        |  0.384   |        0.154        |
# |              GaussianNB              |  0.769   |       0.231        |  0.076   |        0.231        |
# |        DecisionTreeClassifier        |  0.758   |       0.242        |  0.032   |        0.242        |
# |        RandomForestClassifier        |  0.802   |       0.198        |  0.208   |        0.198        |
# ...
